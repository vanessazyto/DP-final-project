# %%
import pandas as pd
import string # for removing punctuaation
import re
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sklearn.feature_extraction.text import CountVectorizer
from wordcloud import WordCloud

# %%
data = pd.read_csv("combined_data.csv", index_col = 0, header = 0)

data.head()
# Out:
#                                            statement   status
# 0                                         oh my gosh  Anxiety
# 1  trouble sleeping, confused mind, restless hear...  Anxiety
# 2  All wrong, back off dear, forward doubt. Stay ...  Anxiety
# 3  I've shifted my focus to something else but I'...  Anxiety
# 4  I'm restless and restless, it's been a month n...  Anxiety

# %%
data.shape
# Out:
# (53043, 2)

# %%
data.isnull().sum()
# Out:
# statement    362
# status         0
# dtype: int64

# %%
data = data.dropna(axis = 0, how = "any")

# %%
data.isnull().sum()
# Out:
# statement    0
# status       0
# dtype: int64

# %%
data.columns
# Out:
# Index(['statement', 'status'], dtype='object')

# %%
data.head()
# Out:
#                                            statement   status
# 0                                         oh my gosh  Anxiety
# 1  trouble sleeping, confused mind, restless hear...  Anxiety
# 2  All wrong, back off dear, forward doubt. Stay ...  Anxiety
# 3  I've shifted my focus to something else but I'...  Anxiety
# 4  I'm restless and restless, it's been a month n...  Anxiety

# %%
data["statement"] = data["statement"].str.lower()
data["status"] = data["status"].str.lower()
data.head()
# Out:
#                                            statement   status
# 0                                         oh my gosh  anxiety
# 1  trouble sleeping, confused mind, restless hear...  anxiety
# 2  all wrong, back off dear, forward doubt. stay ...  anxiety
# 3  i've shifted my focus to something else but i'...  anxiety
# 4  i'm restless and restless, it's been a month n...  anxiety

# %% [markdown]
# Check for duplicates

# %%
duplicates = data[data.duplicated(subset = ("statement", "status"), keep = False)]
duplicates
# Out:
#                                                statement   status
# 18     "no regrets or grudges/angry at things that ha...  anxiety
# 39     but my heart is still restless even though my ...  anxiety
# 56                                      why am i nervous  anxiety
# 88                                               anxious  anxiety
# 97     "no regrets or grudges/angry at things that ha...  anxiety
# ...                                                  ...      ...
# 53038  nobody takes me seriously i’ve (24m) dealt wit...  anxiety
# 53039  selfishness  "i don't feel very good, it's lik...  anxiety
# 53040  is there any way to sleep better? i can't slee...  anxiety
# 53041  public speaking tips? hi, all. i have to give ...  anxiety
# 53042  i have really bad door anxiety! it's not about...  anxiety
#
# [3010 rows x 2 columns]

# %%
print("Examples of duplicated rows (same statement and label):")
print(duplicates.head(10))
# Out:
# Examples of duplicated rows (same statement and label):
#                                              statement   status
# 18   "no regrets or grudges/angry at things that ha...  anxiety
# 39   but my heart is still restless even though my ...  anxiety
# 56                                    why am i nervous  anxiety
# 88                                             anxious  anxiety
# 97   "no regrets or grudges/angry at things that ha...  anxiety
# 132  i want to exhale the restlessness in my chest ...  anxiety
# 138  but my heart is still restless even though my ...  anxiety
# 155                              restless and agitated  anxiety
# 167  i want to exhale the restlessness in my chest ...  anxiety
# 168                  restless restlessness accompanies  anxiety

# %%
data = data.drop_duplicates(subset=["statement", "status"], keep="first")
data.shape
# Out:
# (51071, 2)

# %%
def clean_text(text):
    text = re.sub(r'[^a-zA-Z0-9\s]', '', text)
    text = text.strip()  # Remove leading and trailing spaces
    text = re.sub(r'\s+', ' ', text) # Replace multiple spaces with a single space
    text = re.sub(r'http[s]?://\S+', '', text) # remove HTML links
    
    # remove punctuation
    translator = str.maketrans('', '', string.punctuation)
    text = text.translate(translator)
    
    return text

# %%
data['statement'] = data['statement'].apply(clean_text)
data = data[data['statement'].str.strip() != ""]

# %%
data.head()
# Out:
#                                            statement   status
# 0                                         oh my gosh  anxiety
# 1  trouble sleeping confused mind restless heart ...  anxiety
# 2  all wrong back off dear forward doubt stay in ...  anxiety
# 3  ive shifted my focus to something else but im ...  anxiety
# 4  im restless and restless its been a month now ...  anxiety

# %% [markdown]
# Exploratory Data Analysis

# %%
counts = data["status"].value_counts()
print(counts)

status = list(data["status"].unique())
# Out:
# status
# normal                  16018
# depression              15094
# suicidal                10644
# anxiety                  3620
# bipolar                  2501
# stress                   2296
# personality disorder      895
# Name: count, dtype: int64

# %%
sns.barplot(x = status, y = counts, hue = status, legend = False, palette = 'pastel')

plt.title("Distribution of Mental Health Status Labels", fontsize=14)
plt.xlabel("Mental Health Status", fontsize=12)
plt.ylabel("Number of Samples", fontsize=12)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
data['text_length'] = data['statement'].apply(lambda x: len(x.split()))
sns.boxplot(data = data, x='status', y='text_length', hue = 'status', legend = False, palette = "pastel")
# Out:
# <Axes: xlabel='status', ylabel='text_length'>

# %%
vectorizer = CountVectorizer(stop_words = "english")

# word count matrix
X = vectorizer.fit_transform(data["statement"])
#vectorizer.vocabulary_

# %%
word_counts = np.asarray(X.sum(axis=0)).flatten()

vocabulary = vectorizer.get_feature_names_out()

word_freq = list(zip(vocabulary, word_counts))
word_freq_sorted = sorted(word_freq, key=lambda x: x[1], reverse=True)

top_20_words = word_freq_sorted[:20]


for word, freq in top_20_words:
    print(f"{word}: {freq}")
# Out:
# just: 47405
# like: 36823
# feel: 30485
# want: 26725
# know: 22841
# life: 21532
# im: 19382
# time: 17274
# people: 15911
# really: 15769
# going: 13459
# think: 12628
# day: 11293
# help: 10231
# did: 9582
# things: 9432
# anymore: 9243
# years: 9101
# dont: 9006
# anxiety: 8714

# %%
# function for word frequencies

def top_words_frequency(data, label_column, text_column, label_value, n_words = 20):
    data = data[data[label_column] == label_value]
    vectorizer = CountVectorizer(stop_words = "english")
    X = vectorizer.fit_transform(data[text_column])
    sum_words = X.sum(axis = 0)
    words_freq = [(word, sum_words[0, idx]) for word, idx in vectorizer.vocabulary_.items()]
    words_freq = sorted(words_freq, key=lambda x: x[1], reverse=True)
    top_words = words_freq[:n_words]

    return top_words, dict(words_freq)

# %%
# function for wordcloud
def wordcloud(words_frequencies, title = None, colormap = "gnuplot"):
    wordcloud = WordCloud(background_color = "white", colormap = colormap)
    wordcloud.generate_from_frequencies(words_frequencies)
    plt.figure()
    if title: 
        plt.title(title)
        
    plt.imshow(wordcloud, interpolation = "bilinear")
    plt.axis("off")
    plt.show()

# %% [markdown]
# ### Depression

# %%
depression_top, depression_frequencies = top_words_frequency(data, 'status', 'statement', 'depression')

for word, freq in depression_top:
    print(f"{word}: {freq}")
# Out:
# just: 22810
# like: 17901
# feel: 16199
# want: 11914
# life: 10848
# know: 10656
# time: 8127
# people: 7656
# really: 7066
# depression: 6212
# going: 5830
# day: 5537
# think: 5475
# help: 4712
# did: 4441
# things: 4291
# make: 4093
# anymore: 4029
# work: 4026
# friends: 3981

# %%
wordcloud(depression_frequencies, title = 'WordCloud for Depression')

# %% [markdown]
# ### Anxiety

# %%
anxiety_top, anxiety_frequencies = top_words_frequency(data, 'status', 'statement', 'anxiety')

for word, freq in anxiety_top:
    print(f"{word}: {freq}")
# Out:
# im: 5709
# anxiety: 3472
# just: 3127
# like: 3008
# ive: 2554
# feel: 2122
# dont: 1904
# know: 1722
# time: 1528
# really: 1482
# health: 1123
# going: 1111
# pain: 1094
# heart: 1090
# symptoms: 1086
# feeling: 1085
# think: 1053
# day: 994
# got: 964
# started: 922

# %%
wordcloud(anxiety_frequencies, title = 'WordCloud for Anxiety')

# %% [markdown]
# ### Suicidial

# %%
suicidal_top, suicidal_frequencies = top_words_frequency(data, 'status', 'statement', 'suicidal')

for word, freq in suicidal_top:
    print(f"{word}: {freq}")
# Out:
# just: 14377
# want: 10633
# like: 9094
# life: 7633
# feel: 7517
# know: 6534
# people: 4688
# anymore: 4399
# going: 4267
# time: 4156
# think: 3875
# really: 3850
# die: 3448
# did: 3204
# fucking: 2877
# help: 2872
# years: 2800
# friends: 2795
# day: 2672
# kill: 2606

# %%
wordcloud(suicidal_frequencies, title = 'WordCloud for Suicidal', colormap = "Wistia_r")

# %% [markdown]
# ### Stress

# %%
stress_top, stress_frequencies = top_words_frequency(data, 'status', 'statement', 'stress')

for word, freq in stress_top:
    print(f"{word}: {freq}")
# Out:
# im: 2439
# just: 1523
# like: 1491
# dont: 1152
# feel: 1149
# stress: 1089
# know: 908
# ive: 874
# time: 870
# really: 679
# work: 674
# help: 590
# want: 569
# life: 556
# anxiety: 537
# going: 495
# things: 489
# day: 489
# job: 441
# people: 437

# %%
wordcloud(stress_frequencies, title = 'WordCloud for Stress', colormap = "hot")

# %% [markdown]
# ### Bi-Polar

# %%
bipolar_top, bipolar_frequencies = top_words_frequency(data, 'status', 'statement', 'bipolar')

for word, freq in bipolar_top:
    print(f"{word}: {freq}")
# Out:
# im: 5141
# just: 3079
# like: 2726
# feel: 2167
# ive: 2032
# dont: 2010
# bipolar: 1686
# know: 1619
# really: 1367
# time: 1362
# want: 1190
# life: 978
# going: 929
# people: 868
# meds: 853
# think: 836
# years: 827
# things: 803
# work: 802
# day: 764

# %%
wordcloud(bipolar_frequencies, title = 'WordCloud for Bipolar', colormap = "ocean")

# %% [markdown]
# ### Personality Disorder

# %%
personality_top, personality_frequencies = top_words_frequency(data, 'status', 'statement', 'personality disorder')

for word, freq in personality_top:
    print(f"{word}: {freq}")
# Out:
# im: 1653
# like: 1384
# just: 1213
# dont: 1013
# people: 1002
# feel: 892
# know: 675
# ive: 528
# want: 523
# avpd: 491
# life: 478
# think: 477
# really: 471
# time: 438
# friends: 339
# things: 330
# going: 271
# years: 267
# way: 266
# make: 265

# %%
wordcloud(personality_frequencies, title = 'WordCloud for Personality Disorder', colormap = "ocean")

# %% [markdown]
# ### Normal

# %%
normal_top, normal_frequencies = top_words_frequency(data, 'status', 'statement', 'normal')

for word, freq in normal_top:
    print(f"{word}: {freq}")
# Out:
# im: 1457
# just: 1276
# like: 1219
# want: 1114
# dont: 998
# really: 854
# time: 793
# know: 727
# good: 660
# day: 614
# people: 612
# work: 581
# going: 556
# think: 502
# got: 484
# today: 450
# make: 439
# feel: 439
# did: 426
# need: 412

# %%
wordcloud(normal_frequencies, title = 'WordCloud for Normal', colormap = "hot")

# %% [markdown]
# ## Baseline Model

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report, f1_score, confusion_matrix
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from collections import Counter

# %%
x = data['statement']
y = data['status']

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)

# %%
# train dataset distirbution
target_counts = Counter(y_train)

total = sum(target_counts.values(), 0.0)
for key in target_counts:
    target_counts[key] /= total

print(target_counts)
# Out:
# Counter({'normal': 0.31132682462864014, 'depression': 0.2963325593756119, 'suicidal': 0.21123450918958234, 'anxiety': 0.07125073432735614, 'bipolar': 0.04769631017987523, 'stress': 0.04473102637983607, 'personality disorder': 0.017428035919098105})

# %%
# test dataset distirbution
target_counts = Counter(y_test)

total = sum(target_counts.values(), 0.0)
for key in target_counts:
    target_counts[key] /= total

print(target_counts)
# Out:
# Counter({'normal': 0.3191044970954898, 'depression': 0.29377977938776845, 'suicidal': 0.20187977286077932, 'anxiety': 0.07003459304222961, 'bipolar': 0.051954833235428495, 'stress': 0.045493114026499575, 'personality disorder': 0.01775341035180471})

# %% [markdown]
# ## TF IDF

# %%
vectorizer = CountVectorizer()
vectors = vectorizer.fit_transform(x_train)
vectors.shape
# Out:
# (35747, 62907)

# %%
vectorizer.get_feature_names_out()[:50]
# Out:
# array(['00', '000', '0000', '00000', '000000', '000000062', '000001',
#        '000002', '00002', '00006', '000mg', '000s', '001', '0010',
#        '0011072021', '004', '0055', '007', '008', '0081', '009', '00am',
#        '00b', '00db', '00k', '00lb', '00mb', '00mg', '00mph', '00ms',
#        '00s', '00usd', '01', '010', '0100', '0100mph', '010x5934x4115',
#        '010x5934x4115010x5934x4115', '010x5934x4115jk0op',
#        '010x5934x4115sexyqwrwrwqw', '010x8871x5266',
#        '010x8871x5266010x8871x5266', '011', '011287', '0130', '014',
#        '019', '02', '020', '020123'], dtype=object)

# %%
vectorizer = CountVectorizer(min_df=0.10)
vectors = vectorizer.fit_transform(x_train)



vectorizer.get_feature_names_out()
# Out:
# array(['about', 'after', 'all', 'always', 'am', 'an', 'and', 'anxiety',
#        'any', 'anymore', 'anyone', 'anything', 'are', 'as', 'at', 'back',
#        'bad', 'be', 'because', 'been', 'being', 'better', 'but', 'by',
#        'can', 'cannot', 'could', 'day', 'depression', 'did', 'do', 'dont',
#        'even', 'every', 'everything', 'feel', 'feeling', 'for', 'friends',
#        'from', 'get', 'go', 'going', 'good', 'got', 'had', 'has', 'have',
#        'help', 'here', 'how', 'if', 'im', 'in', 'is', 'it', 'its', 'just',
#        'know', 'life', 'like', 'make', 'me', 'more', 'much', 'my',
#        'myself', 'need', 'never', 'no', 'not', 'nothing', 'now', 'of',
#        'on', 'one', 'only', 'or', 'other', 'out', 'over', 'people',
#        'really', 'right', 'see', 'so', 'some', 'someone', 'something',
#        'still', 'that', 'the', 'them', 'then', 'there', 'they', 'things',
#        'think', 'this', 'time', 'to', 'too', 'up', 'want', 'was', 'way',
# ...

# %%
vectors.shape
# Out:
# (35747, 117)

# %%
vectorizer = TfidfVectorizer(ngram_range=(1, 2), stop_words = "english")
train_vectors = vectorizer.fit_transform(x_train)
test_vectors = vectorizer.transform(x_test)

# %%
log_reg = LogisticRegression(
    random_state=42, solver="saga", max_iter=1_000)
log_reg.fit(train_vectors, y_train)

pred_labels = log_reg.predict(test_vectors)
f1_micro = f1_score(y_test, pred_labels, average="micro")
f1_macro = f1_score(y_test, pred_labels, average="macro")

print(f1_micro)
print(f1_macro)
# Out:
# 0.7537367012597089
# 0.6685362974690496

# %% [markdown]
# Stopwords and lemmatization??

# %%
print(classification_report(y_test, pred_labels))
# Out:
#                       precision    recall  f1-score   support
#
#              anxiety       0.80      0.78      0.79      1073
#              bipolar       0.82      0.66      0.74       796
#           depression       0.67      0.76      0.71      4501
#               normal       0.86      0.91      0.89      4889
# personality disorder       0.91      0.31      0.47       272
#               stress       0.76      0.30      0.43       697
#             suicidal       0.67      0.66      0.66      3093
#
#             accuracy                           0.75     15321
#            macro avg       0.79      0.63      0.67     15321
#         weighted avg       0.76      0.75      0.75     15321

# %%
cm = confusion_matrix(y_test, pred_labels, labels=log_reg.classes_)
sns.heatmap(cm, annot=True, fmt="d", xticklabels=log_reg.classes_, yticklabels=log_reg.classes_, cmap="Blues")
plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("Confusion Matrix: Logistic Regression")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## Naive Bayes

# %%
from sklearn.naive_bayes import MultinomialNB

# %%
nb_model = MultinomialNB()
nb_model.fit(train_vectors, y_train)
# Out:
# MultinomialNB()

# %%
nb_predictions = nb_model.predict(test_vectors)

# %%
print("Naive Bayes - Classification Report:")
print(classification_report(y_test, nb_predictions))

print("F1 Micro:", f1_score(y_test, nb_predictions, average="micro"))
print("F1 Macro:", f1_score(y_test, nb_predictions, average="macro"))
# Out:
# Naive Bayes - Classification Report:
#                       precision    recall  f1-score   support
#
#              anxiety       0.97      0.04      0.07      1073
#              bipolar       0.00      0.00      0.00       796
#           depression       0.35      0.99      0.52      4501
#               normal       0.97      0.47      0.63      4889
# personality disorder       0.00      0.00      0.00       272
#               stress       0.00      0.00      0.00       697
#             suicidal       0.80      0.08      0.15      3093
#
#             accuracy                           0.46     15321
#            macro avg       0.44      0.22      0.20     15321
#         weighted avg       0.64      0.46      0.39     15321
#
# F1 Micro: 0.45858625416095555
# F1 Macro: 0.1957126143481716
# ...

# %%
cm = confusion_matrix(y_test, nb_predictions, labels=log_reg.classes_)
sns.heatmap(cm, annot=True, fmt="d", xticklabels=log_reg.classes_, yticklabels=log_reg.classes_, cmap="Blues")
plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("Confusion Matrix: Naive Bayes")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## SVM??

# %%
from sklearn.svm import LinearSVC

# %%
svc_model = LinearSVC(class_weight = "balanced", random_state = 42, max_iter = 10000)

# %%
svc_model.fit(train_vectors, y_train)
# Out:
# LinearSVC(class_weight='balanced', max_iter=10000, random_state=42)

# %%
svc_predictions = svc_model.predict(test_vectors)

# %%
print("SVM - Classification Report:")
print(classification_report(y_test, svc_predictions))

print("F1 Micro:", f1_score(y_test, svc_predictions, average="micro"))
print("F1 Macro:", f1_score(y_test, svc_predictions, average="macro"))
# Out:
# SVM - Classification Report:
#                       precision    recall  f1-score   support
#
#              anxiety       0.75      0.85      0.80      1073
#              bipolar       0.79      0.78      0.79       796
#           depression       0.73      0.71      0.72      4501
#               normal       0.90      0.90      0.90      4889
# personality disorder       0.77      0.59      0.67       272
#               stress       0.65      0.49      0.56       697
#             suicidal       0.65      0.69      0.67      3093
#
#             accuracy                           0.77     15321
#            macro avg       0.75      0.72      0.73     15321
#         weighted avg       0.77      0.77      0.77     15321
#
# F1 Micro: 0.769270935317538
# F1 Macro: 0.7284525245992471

# %%
# Out:
# Best params: {'C': 1}
# Best macro F1 score: 0.689509403968319

# %%
y_test.head()
# Out:
# 46850                 bipolar
# 50686    personality disorder
# 21086                suicidal
# 43335                  normal
# 49521                 bipolar
# Name: status, dtype: object

# %%
x_test.head()
# Out:
# 46850    i miss my life before diagnosis rationally i k...
# 50686    im screwed maybe many of you are too one thing...
# 21086    i feel like i am finally at the place in my li...
# 43335    reznik 0 bonbonfire another fun confab no matt...
# 49521    i cant believe im like this forever i cant bel...
# Name: statement, dtype: object
